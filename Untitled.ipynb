# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('heart_disease.csv')

# %%
data.drop(columns=['education'], inplace=True)

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds prevalentStroke  \
# 0       Male   39              0         0.0     0.0              no
# 1     Female   46              0         0.0     0.0              no
# 2       Male   48              1        20.0     0.0              no
# 3     Female   61              1        30.0     0.0              no
# 4     Female   46              1        23.0     0.0              no
# ...      ...  ...            ...         ...     ...             ...
# 4231    Male   58              0         0.0     0.0              no
# 4232    Male   68              0         0.0     0.0              no
# 4233    Male   50              1         1.0     0.0              no
# 4234    Male   51              1        43.0     0.0              no
# 4237  Female   52              0         0.0     0.0              no
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# 1                0         0    250.0  121.0   81.0  28.73       95.0
# 2                0         0    245.0  127.5   80.0  25.34       75.0
# 3                1         0    225.0  150.0   95.0  28.58       65.0
# 4                0         0    285.0  130.0   84.0  23.10       85.0
# ...            ...       ...      ...    ...    ...    ...        ...
# 4231             1         0    187.0  141.0   81.0  24.96       80.0
# 4232             1         0    176.0  168.0   97.0  23.14       60.0
# 4233             1         0    313.0  179.0   92.0  25.97       66.0
# 4234             0         0    207.0  126.5   80.0  19.71       65.0
# 4237             0         0    269.0  133.5   83.0  21.47       80.0
#
#       glucose Heart_ stroke
# 0        77.0            No
# 1        76.0            No
# 2        70.0            No
# 3       103.0           yes
# 4        85.0            No
# ...       ...           ...
# 4231     81.0            No
# 4232     79.0           yes
# 4233     86.0           yes
# 4234     68.0            No
# 4237    107.0            No
#
# [3749 rows x 15 columns]

# %%
data['Gender'] = data['Gender'].replace(['Male','Female'],(1,0))
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_14268\1197857528.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Gender'] = data['Gender'].replace(['Male','Female'],(1,0))

# %%
data
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds prevalentStroke  \
# 0          1   39              0         0.0     0.0              no
# 1          0   46              0         0.0     0.0              no
# 2          1   48              1        20.0     0.0              no
# 3          0   61              1        30.0     0.0              no
# 4          0   46              1        23.0     0.0              no
# ...      ...  ...            ...         ...     ...             ...
# 4231       1   58              0         0.0     0.0              no
# 4232       1   68              0         0.0     0.0              no
# 4233       1   50              1         1.0     0.0              no
# 4234       1   51              1        43.0     0.0              no
# 4237       0   52              0         0.0     0.0              no
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# 1                0         0    250.0  121.0   81.0  28.73       95.0
# 2                0         0    245.0  127.5   80.0  25.34       75.0
# 3                1         0    225.0  150.0   95.0  28.58       65.0
# 4                0         0    285.0  130.0   84.0  23.10       85.0
# ...            ...       ...      ...    ...    ...    ...        ...
# 4231             1         0    187.0  141.0   81.0  24.96       80.0
# 4232             1         0    176.0  168.0   97.0  23.14       60.0
# 4233             1         0    313.0  179.0   92.0  25.97       66.0
# 4234             0         0    207.0  126.5   80.0  19.71       65.0
# 4237             0         0    269.0  133.5   83.0  21.47       80.0
#
#       glucose Heart_ stroke
# 0        77.0            No
# 1        76.0            No
# 2        70.0            No
# 3       103.0           yes
# 4        85.0            No
# ...       ...           ...
# 4231     81.0            No
# 4232     79.0           yes
# 4233     86.0           yes
# 4234     68.0            No
# 4237    107.0            No
#
# [3749 rows x 15 columns]

# %%
data.prevalentStroke.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data['prevalentStroke']=data['prevalentStroke'].replace(['yes','no'],[1,0])
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_14268\2579216552.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['prevalentStroke']=data['prevalentStroke'].replace(['yes','no'],[1,0])

# %%
data
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0          1   39              0         0.0     0.0                0
# 1          0   46              0         0.0     0.0                0
# 2          1   48              1        20.0     0.0                0
# 3          0   61              1        30.0     0.0                0
# 4          0   46              1        23.0     0.0                0
# ...      ...  ...            ...         ...     ...              ...
# 4231       1   58              0         0.0     0.0                0
# 4232       1   68              0         0.0     0.0                0
# 4233       1   50              1         1.0     0.0                0
# 4234       1   51              1        43.0     0.0                0
# 4237       0   52              0         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# 1                0         0    250.0  121.0   81.0  28.73       95.0
# 2                0         0    245.0  127.5   80.0  25.34       75.0
# 3                1         0    225.0  150.0   95.0  28.58       65.0
# 4                0         0    285.0  130.0   84.0  23.10       85.0
# ...            ...       ...      ...    ...    ...    ...        ...
# 4231             1         0    187.0  141.0   81.0  24.96       80.0
# 4232             1         0    176.0  168.0   97.0  23.14       60.0
# 4233             1         0    313.0  179.0   92.0  25.97       66.0
# 4234             0         0    207.0  126.5   80.0  19.71       65.0
# 4237             0         0    269.0  133.5   83.0  21.47       80.0
#
#       glucose Heart_ stroke
# 0        77.0            No
# 1        76.0            No
# 2        70.0            No
# 3       103.0           yes
# 4        85.0            No
# ...       ...           ...
# 4231     81.0            No
# 4232     79.0           yes
# 4233     86.0           yes
# 4234     68.0            No
# 4237    107.0            No
#
# [3749 rows x 15 columns]

# %%
data['Heart_ stroke'] = data['Heart_ stroke'].replace(['yes','No'],[1,0])
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_14268\17647100.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Heart_ stroke'] = data['Heart_ stroke'].replace(['yes','No'],[1,0])

# %%
data
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0          1   39              0         0.0     0.0                0
# 1          0   46              0         0.0     0.0                0
# 2          1   48              1        20.0     0.0                0
# 3          0   61              1        30.0     0.0                0
# 4          0   46              1        23.0     0.0                0
# ...      ...  ...            ...         ...     ...              ...
# 4231       1   58              0         0.0     0.0                0
# 4232       1   68              0         0.0     0.0                0
# 4233       1   50              1         1.0     0.0                0
# 4234       1   51              1        43.0     0.0                0
# 4237       0   52              0         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# 1                0         0    250.0  121.0   81.0  28.73       95.0
# 2                0         0    245.0  127.5   80.0  25.34       75.0
# 3                1         0    225.0  150.0   95.0  28.58       65.0
# 4                0         0    285.0  130.0   84.0  23.10       85.0
# ...            ...       ...      ...    ...    ...    ...        ...
# 4231             1         0    187.0  141.0   81.0  24.96       80.0
# 4232             1         0    176.0  168.0   97.0  23.14       60.0
# 4233             1         0    313.0  179.0   92.0  25.97       66.0
# 4234             0         0    207.0  126.5   80.0  19.71       65.0
# 4237             0         0    269.0  133.5   83.0  21.47       80.0
#
#       glucose  Heart_ stroke
# 0        77.0              0
# 1        76.0              0
# 2        70.0              0
# 3       103.0              1
# 4        85.0              0
# ...       ...            ...
# 4231     81.0              0
# 4232     79.0              1
# 4233     86.0              1
# 4234     68.0              0
# 4237    107.0              0
#
# [3749 rows x 15 columns]

# %%
data_input= data.drop(columns=['Heart_ stroke'])
data_output=data['Heart_ stroke']

# %%
data_output.value_counts()
# Out:
# Heart_ stroke
# 0    3177
# 1     572
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(random_state=2)

# %%
data_input, data_output = sm.fit_resample(data_input, data_output.ravel())
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_14268\2967831284.py:1: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   data_input, data_output = sm.fit_resample(data_input, data_output.ravel())

# %%
np.unique(data_output, return_counts=True)
# Out:
# (array([0, 1], dtype=int64), array([3177, 3177], dtype=int64))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(data_input, data_output, test_size = 0.2)

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\rishi\Desktop\sample_project_1\env\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.6451612903225806

# %%
input = np.array([[0,46,1,10,0,0,0,0,191,112,88,23.38,70,89]])

# %%
x = model.predict(input)
# Out:
# C:\Users\rishi\Desktop\sample_project_1\env\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
x[0]
# Out:
# 0

# %%
import pickle as pk

# %%
pk.dump(model,open('Heart_disease_model3.pkl','wb'))
